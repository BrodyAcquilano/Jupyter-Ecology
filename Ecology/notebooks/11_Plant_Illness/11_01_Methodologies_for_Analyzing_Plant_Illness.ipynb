# %% [markdown]
# ```markdown
# # 01. Methodologies for Analyzing Plant Illness
#
# ## From Initial Observation to Evidence, Diagnosis, Population Analysis, and Treatment
#
# Plant illness is rarely explained by a single visible symptom.
#
# A damaged leaf, broken branch, patch of missing bark, fungal growth, insect hole, or declining crown may have many possible causes. Some symptoms indicate serious threats to the survival or structural stability of a tree, while others are temporary, cosmetic, seasonal, or part of ordinary ecological interactions.
#
# This notebook develops a general methodology for investigating plant illness.
#
# The central question is:
#
# $$
# \text{How do we move from an initial observation to a defensible conclusion?}
# $$
#
# The investigation will consider:
#
# - how plant illness and damage should be defined;
# - how plants resist infection and recover from injury;
# - the major biological, environmental, and human causes of plant decline;
# - how symptoms and signs can be observed systematically;
# - how competing explanations can be compared;
# - how the seriousness of an issue can be evaluated;
# - how individual plants and larger populations can be sampled;
# - how disease prevalence and severity can be measured;
# - how spatial and temporal patterns can be analyzed;
# - how treatments or management responses can be evaluated;
# - what conclusions are possible with limited equipment, time, and expertise.
#
# This introductory notebook does not attempt to diagnose a particular tree or conduct a complete field study.
#
# Instead, it establishes the conceptual and methodological foundation for later notebooks involving field observations, municipal tree inventories, maps, photographs, statistical analysis, and possible treatment strategies.
# ```
#
# ```markdown
# ## 1. Purpose of the Study
#
# The purpose of this project is to develop a repeatable method for studying plant illness in urban environments.
#
# The project begins with visible observations such as:
#
# - dark spots on leaves;
# - missing leaf tissue;
# - discoloured foliage;
# - broken or hanging branches;
# - dead branches;
# - missing bark;
# - wounds on trunks or roots;
# - exposed or severed roots;
# - unusual fungal structures;
# - web-like material;
# - insect holes;
# - declining or unusually sparse crowns;
# - new shoots growing from stressed trunks or branches.
#
# These observations may suggest that a plant is unhealthy, but they do not automatically identify the cause.
#
# The methodology must therefore distinguish between four stages:
#
# $$
# \text{Observation}
# \rightarrow
# \text{Description}
# \rightarrow
# \text{Analysis}
# \rightarrow
# \text{Conclusion}
# $$
#
# An **observation** records what is visible.
#
# A **description** converts the observation into measurable characteristics.
#
# An **analysis** compares possible explanations using additional evidence.
#
# A **conclusion** states what the available evidence supports, including the remaining uncertainty.
#
# The goal is not merely to name diseases. The goal is to understand what happened, how serious it is, how common it is, what evidence supports the explanation, and what actions may be appropriate.
# ```
#
# ```markdown
# ## 2. Observation Is Not Diagnosis
#
# A visible symptom is evidence that something has occurred, but it is not necessarily evidence of one specific cause.
#
# For example, a hanging branch might have resulted from:
#
# - wind;
# - ice;
# - mechanical impact;
# - poor attachment;
# - internal decay;
# - pruning;
# - vandalism;
# - animal activity;
# - a previous infection;
# - several interacting causes.
#
# Similarly, a hole in a leaf might have resulted from:
#
# - insect feeding;
# - physical tearing;
# - hail;
# - abrasion;
# - dead tissue falling away;
# - a bacterial lesion;
# - a fungal lesion;
# - ordinary accumulated damage.
#
# A responsible investigation must avoid moving directly from:
#
# $$
# \text{I observed damage}
# $$
#
# to:
#
# $$
# \text{I know what caused the damage}
# $$
#
# Instead, the appropriate sequence is:
#
# $$
# \boxed{
# \text{Observed condition}
# \rightarrow
# \text{possible explanations}
# \rightarrow
# \text{additional evidence}
# \rightarrow
# \text{provisional diagnosis}
# }
# $$
#
# The word **provisional** is important.
#
# A field diagnosis may remain uncertain unless it is supported by expert inspection, microscopy, culturing, DNA analysis, soil testing, chemical analysis, or other specialized methods.
# ```
#
# ```markdown
# ## 3. Signs, Symptoms, Causes, and Diagnoses
#
# Several terms should be kept separate throughout the project.
#
# ### Symptom
#
# A symptom is a response of the plant.
#
# Examples include:
#
# - yellowing;
# - wilting;
# - leaf spots;
# - tissue death;
# - early leaf loss;
# - crown thinning;
# - branch dieback;
# - cracking;
# - swelling;
# - reduced growth.
#
# ### Sign
#
# A sign is direct physical evidence of a biological agent.
#
# Examples may include:
#
# - fungal fruiting bodies;
# - spores;
# - visible mycelium;
# - bacterial ooze;
# - insect larvae;
# - eggs;
# - feeding galleries;
# - shed insect skins;
# - frass.
#
# ### Injury
#
# An injury is physical or chemical damage that may not involve a living pathogen.
#
# Examples include:
#
# - broken branches;
# - cuts;
# - girdling;
# - salt injury;
# - heat injury;
# - frost injury;
# - root severing;
# - herbicide exposure;
# - vehicle impact.
#
# ### Cause
#
# A cause is the process or agent responsible for the condition.
#
# ### Diagnosis
#
# A diagnosis is a reasoned identification of the cause based on the available evidence.
#
# A diagnosis should explain more than the appearance of the plant. It should also be consistent with:
#
# - the host species;
# - the affected tissue;
# - the symptom pattern;
# - the season;
# - the location;
# - the environmental conditions;
# - the likely transmission pathway;
# - the progression of the condition over time.
# ```
#
# ```markdown
# ## 4. What Does Plant Illness Mean?
#
# Plant illness can be defined in several ways.
#
# A plant may be considered unhealthy when its ability to survive, grow, reproduce, maintain its structure, or perform normal physiological functions has been reduced.
#
# However, visible damage does not always produce a meaningful reduction in overall health.
#
# For example:
#
# - a tree may lose some leaves and remain healthy;
# - a leaf disease may appear dramatic but remain mostly cosmetic;
# - a tree may replace damaged foliage;
# - a branch may die while the rest of the tree remains stable;
# - a root or vascular disease may be serious even when leaf symptoms are initially limited;
# - internal decay may create structural risk without immediately killing the tree.
#
# Plant health should therefore be treated as a multidimensional condition.
#
# A conceptual representation is:
#
# $$
# H_i =
# f(
# L_i,
# C_i,
# B_i,
# T_i,
# R_i,
# G_i,
# P_i,
# E_i
# )
# $$
#
# Where:
#
# - $$H_i$$ = overall condition of plant $$i$$;
# - $$L_i$$ = leaf condition;
# - $$C_i$$ = crown condition;
# - $$B_i$$ = branch condition;
# - $$T_i$$ = trunk or stem condition;
# - $$R_i$$ = root condition;
# - $$G_i$$ = growth and regeneration;
# - $$P_i$$ = pests or pathogens;
# - $$E_i$$ = environmental conditions.
#
# This equation is conceptual rather than a validated health formula.
#
# It shows that whole-plant health cannot be determined from a single damaged leaf.
# ```
#
# ```markdown
# ## 5. The Plant Disease Triangle
#
# A traditional model of plant disease considers three interacting components:
#
# 1. a susceptible host;
# 2. a harmful agent;
# 3. environmental conditions that support disease.
#
# This relationship can be written as:
#
# $$
# \text{Disease}
# =
# f(
# \text{Host},
# \text{Agent},
# \text{Environment}
# )
# $$
#
# For an urban tree study, this model can be expanded:
#
# $$
# D_i(t)
# =
# f(
# H_i,
# A_i,
# E_i(t),
# W_i(t),
# V_i(t),
# M_i(t)
# )
# $$
#
# Where:
#
# - $$D_i(t)$$ = disease or damage outcome for plant $$i$$ at time $$t$$;
# - $$H_i$$ = host characteristics;
# - $$A_i$$ = biological or non-biological agent;
# - $$E_i(t)$$ = environmental conditions;
# - $$W_i(t)$$ = wounds and structural damage;
# - $$V_i(t)$$ = vectors and transmission pathways;
# - $$M_i(t)$$ = maintenance and management history.
#
# This expanded model recognizes that an urban tree may be influenced by planting conditions, road salt, pruning, root restriction, construction, irrigation, drought, insects, fungi, bacteria, and human activity at the same time.
# ```
#
# ```markdown
# ## 6. Plant Barriers and Defence Mechanisms
#
# Plants are not passive surfaces on which organisms grow.
#
# They possess physical, chemical, physiological, and ecological barriers that can prevent infection or limit damage.
#
# ### Physical Barriers
#
# Physical barriers include:
#
# - bark;
# - waxy leaf cuticles;
# - outer epidermal tissue;
# - cell walls;
# - tightly sealed plant surfaces;
# - protective bud scales;
# - natural barriers between tissues.
#
# These structures can make it difficult for pathogens to reach vulnerable internal tissue.
#
# ### Chemical Defences
#
# Plants may produce compounds that:
#
# - inhibit fungal growth;
# - discourage insect feeding;
# - damage invading organisms;
# - signal nearby cells;
# - reinforce cell walls;
# - isolate infected tissue.
#
# ### Localized Defence
#
# Plants may isolate or sacrifice small areas of tissue to prevent further spread.
#
# Possible responses include:
#
# - localized cell death;
# - formation of barriers around damaged wood;
# - sealing of wounds;
# - compartmentalization of decay;
# - shedding infected leaves;
# - abandoning damaged twigs or branches.
#
# ### Regrowth and Compensation
#
# Plants may compensate for tissue loss through:
#
# - new leaf production;
# - activation of dormant buds;
# - new shoots;
# - increased growth in surviving tissue;
# - redistribution of resources;
# - replacement of damaged roots or branches.
#
# New growth does not automatically prove that the plant is responding to disease. It may also be ordinary seasonal growth.
#
# ### Microbial Defence
#
# Plants interact with communities of bacteria, fungi, and other microorganisms.
#
# Some microorganisms may:
#
# - compete with pathogens;
# - occupy potential infection sites;
# - produce inhibitory compounds;
# - assist nutrient uptake;
# - improve tolerance to stress;
# - stimulate plant defence responses.
#
# A visible fungus is therefore not automatically harmful. It may be pathogenic, neutral, beneficial, or decomposing tissue that was already dead.
# ```
#
# ```markdown
# ## 7. How Plant Barriers Are Bypassed
#
# A pathogen or pest may reach plant tissue through several routes.
#
# Possible entry pathways include:
#
# - natural openings in leaves;
# - young or developing tissue;
# - damaged roots;
# - broken branches;
# - pruning wounds;
# - cracks in bark;
# - insect feeding wounds;
# - frost cracks;
# - mechanical injuries;
# - storm damage;
# - contact with infected roots;
# - contaminated soil;
# - contaminated water;
# - infected plant material;
# - contaminated tools.
#
# The presence of a wound may increase the possibility of infection, but a wound alone does not prove that infection occurred.
#
# Likewise, disease near a wound does not necessarily prove that the wound happened first.
#
# Several causal sequences are possible:
#
# $$
# \text{Wound}
# \rightarrow
# \text{infection}
# \rightarrow
# \text{decline}
# $$
#
# $$
# \text{Infection}
# \rightarrow
# \text{weakened tissue}
# \rightarrow
# \text{branch failure}
# $$
#
# $$
# \text{Environmental stress}
# \rightarrow
# \text{reduced defence}
# \rightarrow
# \text{infection}
# \rightarrow
# \text{structural damage}
# $$
#
# Determining the order of events may require repeated observations, examination of internal tissue, maintenance records, weather records, or professional assessment.
# ```
#
# ```markdown
# ## 8. Major Categories of Plant Illness and Damage
#
# Plant illness should initially be classified into broad causal categories.
#
# These categories prevent the investigation from assuming that every abnormality is an infectious disease.
#
# ### 8.1 Pathogens
#
# Potential pathogens include:
#
# - fungi;
# - fungus-like organisms;
# - bacteria;
# - viruses;
# - viroids;
# - phytoplasmas;
# - nematodes;
# - parasitic plants.
#
# ### 8.2 Insects and Other Animals
#
# Possible animal-related causes include:
#
# - leaf-chewing insects;
# - sap-feeding insects;
# - bark beetles;
# - wood-boring insects;
# - leaf miners;
# - gall-forming organisms;
# - mites;
# - caterpillars;
# - vertebrate browsing;
# - bark stripping;
# - nesting or burrowing activity.
#
# Some insects directly damage plants.
#
# Others act as vectors that transport pathogens between plants.
#
# ### 8.3 Environmental Stress
#
# Possible environmental stressors include:
#
# - high temperatures;
# - drought;
# - flooding;
# - poor drainage;
# - frost;
# - ice;
# - wind;
# - insufficient sunlight;
# - excessive sunlight;
# - nutrient deficiency;
# - nutrient toxicity;
# - soil compaction;
# - poor soil structure;
# - restricted rooting space;
# - low oxygen around roots;
# - road salt;
# - air pollution;
# - changing seasonal conditions.
#
# ### 8.4 Physical Injury
#
# Possible sources of physical injury include:
#
# - storms;
# - falling objects;
# - vehicles;
# - bicycles;
# - construction equipment;
# - lawn maintenance equipment;
# - pruning;
# - staking materials;
# - wires;
# - signs;
# - drilling;
# - cutting;
# - root excavation;
# - pedestrian traffic;
# - animal activity;
# - vandalism.
#
# ### 8.5 Management and Planting Conditions
#
# Management-related factors include:
#
# - poor pruning technique;
# - delayed pruning;
# - incorrect planting depth;
# - restricted planting pits;
# - excessive mulch;
# - insufficient mulch;
# - inadequate watering;
# - excessive watering;
# - incompatible soil;
# - damaged nursery stock;
# - poor species selection;
# - repeated disturbance.
#
# ### 8.6 Normal or Low-Concern Processes
#
# Not every unusual observation is evidence of serious illness.
#
# Possibilities include:
#
# - ordinary leaf aging;
# - seasonal leaf loss;
# - minor insect feeding;
# - harmless fungal growth;
# - lichen;
# - moss;
# - old pruning wounds;
# - natural bark shedding;
# - branch self-pruning;
# - minor cosmetic leaf disease;
# - decomposition of tissue that was already dead.
# ```
#
# ```markdown
# ## 9. Primary, Secondary, and Opportunistic Agents
#
# The organism most visible on a damaged tree may not be the original cause of decline.
#
# ### Primary Agent
#
# A primary agent can attack relatively healthy tissue and initiate the condition.
#
# ### Secondary Agent
#
# A secondary agent attacks tissue that has already been weakened by another stressor.
#
# ### Opportunistic Organism
#
# An opportunistic organism takes advantage of damaged, dying, or dead tissue.
#
# ### Decomposer
#
# A decomposer breaks down tissue after it has died.
#
# A possible sequence is:
#
# $$
# \text{Drought}
# \rightarrow
# \text{reduced plant defence}
# \rightarrow
# \text{insect attack}
# \rightarrow
# \text{branch death}
# \rightarrow
# \text{fungal decomposition}
# $$
#
# In this example, the visible fungus might not have caused the original decline.
#
# The methodology must therefore ask:
#
# - Did the organism attack healthy tissue?
# - Was the tissue already injured?
# - Was the plant already stressed?
# - Is the organism spreading into living tissue?
# - Is the organism restricted to dead material?
# - Is the visible organism a pathogen, an opportunist, or a decomposer?
# ```
#
# ```markdown
# ## 10. Transmission Pathways and Vectors
#
# A vector is an organism that carries a pathogen from one host to another.
#
# Examples may include:
#
# - beetles;
# - aphids;
# - leafhoppers;
# - mites;
# - nematodes;
# - birds;
# - mammals;
# - humans.
#
# Not every transmission pathway requires a living vector.
#
# Other pathways include:
#
# - wind;
# - rain splash;
# - surface water;
# - groundwater;
# - connected roots;
# - soil movement;
# - contaminated pruning tools;
# - nursery stock;
# - transported firewood;
# - fallen leaves;
# - infected seeds;
# - movement of branches or wood debris.
#
# For field observations, it may be useful to record both:
#
# - **Suspected Agent**
# - **Suspected Transmission or Damage Pathway**
#
# This avoids incorrectly calling wind, tools, or water biological vectors while still including them in the causal analysis.
# ```
#
# ```markdown
# ## 11. Types of Plant Disease by Affected Tissue
#
# Plant diseases and injuries can also be organized by the tissue or system affected.
#
# ### Foliage Conditions
#
# These may involve:
#
# - leaf spots;
# - blights;
# - mildew;
# - rusts;
# - galls;
# - chlorosis;
# - necrosis;
# - premature leaf loss;
# - holes;
# - skeletonization;
# - leaf mines.
#
# ### Shoot and Twig Conditions
#
# These may involve:
#
# - shoot blight;
# - dead buds;
# - distorted growth;
# - twig dieback;
# - witches' broom;
# - stunted shoots.
#
# ### Branch Conditions
#
# These may involve:
#
# - branch dieback;
# - cankers;
# - structural fractures;
# - decay;
# - weak branch unions;
# - hanging branches;
# - bark loss;
# - pruning wounds.
#
# ### Trunk and Stem Conditions
#
# These may involve:
#
# - cankers;
# - cavities;
# - cracking;
# - missing bark;
# - decay;
# - insect galleries;
# - fungal fruiting bodies;
# - bleeding or oozing;
# - girdling;
# - included bark.
#
# ### Vascular Conditions
#
# These may interfere with water or nutrient transport.
#
# Possible symptoms include:
#
# - wilting;
# - rapid crown decline;
# - discoloured vascular tissue;
# - one-sided branch decline;
# - reduced growth.
#
# ### Root and Root-Collar Conditions
#
# These may involve:
#
# - root decay;
# - root severing;
# - girdling roots;
# - compacted soil;
# - poor drainage;
# - excavation damage;
# - exposed roots;
# - root-collar burial;
# - fungal infection.
#
# Root conditions may be difficult to detect because much of the relevant tissue is underground.
# ```
#
# ```markdown
# ## 12. A Diagnostic Question Tree
#
# The diagnostic process can be approached like a dichotomous key.
#
# It does not immediately identify a species or disease. Instead, it narrows the possible causal categories.
#
# ### Step 1: Is the plant actually abnormal?
#
# Ask:
#
# - Is the feature present on healthy plants of the same species?
# - Is it normal for the season?
# - Is it ordinary bark texture, leaf shape, or growth?
# - Is it old damage rather than active damage?
# - Is the apparent growth lichen, moss, or another harmless organism?
#
# ### Step 2: Which tissue is affected?
#
# Choose the primary location:
#
# - leaves;
# - buds;
# - shoots;
# - branches;
# - trunk;
# - bark;
# - roots;
# - flowers;
# - fruit;
# - the entire plant.
#
# ### Step 3: Is the damage localized or widespread?
#
# Determine whether the condition affects:
#
# - one leaf;
# - one branch;
# - one side of the crown;
# - the entire crown;
# - one tree;
# - several nearby trees;
# - several species;
# - an entire site.
#
# ### Step 4: Is there evidence of a living agent?
#
# Look for:
#
# - fungal structures;
# - spores;
# - mycelium;
# - insects;
# - eggs;
# - larvae;
# - galleries;
# - frass;
# - bacterial ooze;
# - repeated feeding patterns.
#
# ### Step 5: Is there evidence of physical injury?
#
# Look for:
#
# - clean cuts;
# - jagged breaks;
# - torn fibres;
# - impact marks;
# - severed roots;
# - machinery wounds;
# - ties or wires;
# - construction disturbance;
# - bark scraping.
#
# ### Step 6: Is there evidence of environmental stress?
#
# Consider:
#
# - heat;
# - drought;
# - flooding;
# - soil compaction;
# - road salt;
# - limited rooting area;
# - recent excavation;
# - unusual weather;
# - poor drainage.
#
# ### Step 7: What pattern does the damage follow?
#
# Ask whether the pattern follows:
#
# - a road;
# - a drainage area;
# - one tree species;
# - a planting date;
# - a pruning zone;
# - a construction area;
# - a cluster;
# - a random distribution;
# - prevailing wind;
# - connected root systems.
#
# ### Step 8: Is the condition progressing?
#
# Repeated observations should determine whether it is:
#
# - stable;
# - spreading;
# - recovering;
# - recurring seasonally;
# - appearing on additional trees;
# - producing new structural problems.
# ```
#
# ```markdown
# ## 13. Determining Whether an Issue Is Serious
#
# The visual size of a symptom is not always equal to its biological seriousness.
#
# A condition should be evaluated using several dimensions.
#
# ### 13.1 Tissue Importance
#
# Damage to different tissues has different consequences.
#
# Leaf damage may reduce photosynthesis but may be temporary.
#
# Root, vascular, trunk, and structural damage may have greater long-term consequences.
#
# ### 13.2 Extent
#
# The amount of tissue affected should be estimated.
#
# Examples include:
#
# - percentage of leaf area damaged;
# - percentage of leaves affected;
# - percentage of crown affected;
# - percentage of branches dead;
# - percentage of trunk circumference damaged;
# - number of exposed or severed roots.
#
# ### 13.3 Rate of Progression
#
# A rapidly expanding condition may require more concern than stable old damage.
#
# ### 13.4 Structural Risk
#
# A tree may remain alive while becoming structurally dangerous.
#
# Potential concerns include:
#
# - large hanging branches;
# - major cavities;
# - extensive decay;
# - root instability;
# - trunk cracks;
# - weak branch unions;
# - substantial bark loss around the trunk.
#
# ### 13.5 Host Importance
#
# The consequences may depend on whether the plant is:
#
# - rare;
# - old;
# - culturally important;
# - part of a protected population;
# - a major shade tree;
# - near buildings or walkways;
# - one of many replaceable ornamental plants.
#
# ### 13.6 Population Spread
#
# A condition affecting one tree may be less urgent than one rapidly appearing across many trees.
#
# ### 13.7 Reversibility
#
# The investigation should ask whether the condition is:
#
# - naturally recoverable;
# - manageable;
# - treatable;
# - preventable;
# - irreversible;
# - likely to recur.
# ```
#
# ```markdown
# ## 14. A Provisional Seriousness Framework
#
# A preliminary seriousness classification can be used before a professional diagnosis is available.
#
# | Level | Interpretation | Example Characteristics |
# |---|---|---|
# | 0 | No visible concern | No abnormal symptoms observed |
# | 1 | Minor or cosmetic | Small leaf spots, minor feeding, old wound |
# | 2 | Moderate | Repeated symptoms, limited branch dieback, noticeable defoliation |
# | 3 | Substantial | Large affected area, multiple dead branches, expanding damage |
# | 4 | Severe | Major crown decline, large wounds, root or trunk concerns |
# | 5 | Critical | Immediate structural concern, rapid decline, widespread mortality |
#
# This classification is observational.
#
# It should not be presented as a validated medical or arboricultural scale unless it is later connected to an established assessment system.
#
# Different parts of the same tree should be scored separately.
#
# For example:
#
# | Tree Component | Score |
# |---|---:|
# | Leaves | 2 |
# | Crown | 1 |
# | Branches | 3 |
# | Trunk | 1 |
# | Root Zone | Unknown |
#
# This prevents a serious branch hazard from being hidden inside an average whole-tree score.
# ```
#
# ```markdown
# ## 15. Building Competing Hypotheses
#
# Every important observation should generate multiple plausible explanations.
#
# For example, consider a partially detached branch.
#
# Possible hypotheses include:
#
# 1. the branch was broken by wind;
# 2. the branch was damaged by ice;
# 3. the branch was struck by a person or object;
# 4. the branch failed because of a weak attachment;
# 5. decay weakened the branch before it broke;
# 6. the branch was partly cut during maintenance;
# 7. improper pruning left the branch attached;
# 8. an animal damaged the branch;
# 9. the branch was intentionally damaged;
# 10. several causes acted together.
#
# The purpose of the investigation is not to list possibilities forever.
#
# The purpose is to identify evidence that distinguishes them.
#
# | Hypothesis | Supporting Evidence | Contradicting Evidence | Evidence Still Needed |
# |---|---|---|---|
# | Wind breakage | Jagged fibres, recent wind event | Smooth tool marks | Weather date, close photographs |
# | Pruning | Repeated cuts, municipal work | Random tear pattern | Maintenance records |
# | Internal decay | Soft or discoloured wood | Healthy internal tissue | Arborist inspection |
# | Mechanical impact | Scraping or impact pattern | No external injury | Site history |
# | Intentional damage | Repeated targeted marks | Ordinary maintenance pattern | Strong physical or documentary evidence |
#
# Unusual explanations should remain possible when appropriate, but they should not receive greater weight than the evidence supports.
# ```
#
# ```markdown
# ## 16. Evidence and Confidence
#
# Not all evidence has the same strength.
#
# ### Low-Strength Evidence
#
# Examples include:
#
# - resemblance to an online photograph;
# - one observation;
# - an uncertain memory;
# - a symptom shared by many diseases;
# - assumptions about what happened before arrival.
#
# ### Moderate-Strength Evidence
#
# Examples include:
#
# - repeated observations;
# - characteristic symptom patterns;
# - confirmed host species;
# - appropriate seasonal timing;
# - similar symptoms on nearby plants;
# - weather or maintenance records.
#
# ### High-Strength Evidence
#
# Examples include:
#
# - characteristic signs of the causal agent;
# - professional arborist assessment;
# - microscopy;
# - laboratory culturing;
# - molecular identification;
# - chemical testing;
# - internal structural assessment;
# - confirmed municipal maintenance records.
#
# A confidence field can accompany every diagnosis:
#
# - **Low confidence**
# - **Moderate confidence**
# - **High confidence**
# - **Confirmed**
#
# The absence of certainty is not a failure.
#
# Recording uncertainty is part of the scientific result.
# ```
#
# ```markdown
# ## 17. Field Observation Card
#
# The following table can serve as a preliminary field-record template.
#
# | Field | Entry |
# |---|---|
# | Observation ID | |
# | Tree ID or Tag Number | |
# | Date | |
# | Time | |
# | Observer | |
# | Latitude | |
# | Longitude | |
# | Street or Site | |
# | Tree Species | |
# | Species Confidence | |
# | Approximate Size | |
# | Diameter at Breast Height | |
# | Site Type | |
# | Primary Tissue Affected | |
# | Symptom Description | |
# | Sign of Agent Present | |
# | Estimated Severity | |
# | Crown Condition | |
# | Branch Condition | |
# | Trunk and Bark Condition | |
# | Visible Root Condition | |
# | Soil Condition | |
# | Moisture Condition | |
# | Nearby Construction | |
# | Evidence of Pruning | |
# | Evidence of Insects | |
# | Evidence of Fungi | |
# | Evidence of Physical Damage | |
# | Suspected Causal Categories | |
# | Alternative Explanations | |
# | Photographs Taken | |
# | Follow-Up Required | |
# | Diagnostic Confidence | |
# | Additional Notes | |
#
# This card can later be converted into:
#
# - a spreadsheet;
# - a GeoDataFrame;
# - a mobile form;
# - a database;
# - a geographic information system layer.
# ```
#
# ```markdown
# ## 18. Photographing Evidence
#
# Photographs should be collected systematically rather than only as close-up images of the most dramatic symptom.
#
# For each tree, useful photographs may include:
#
# 1. the surrounding site;
# 2. the entire tree;
# 3. the full crown;
# 4. the trunk;
# 5. the root collar;
# 6. the visible root zone;
# 7. the affected branch;
# 8. the upper and lower leaf surfaces;
# 9. a close-up of signs or symptoms;
# 10. a scale reference;
# 11. nearby trees for comparison;
# 12. the tree tag or inventory number.
#
# Photographs should record enough context to answer:
#
# - Where is the symptom located?
# - How much of the tree is affected?
# - Is the damage isolated or repeated?
# - Is the condition associated with a wound?
# - Are nearby trees affected?
# - Has the condition changed during later visits?
#
# Repeated photographs should be taken from similar positions whenever possible.
# ```
#
# ```markdown
# ## 19. Tree Identification
#
# Tree species should be identified before assigning a disease whenever possible.
#
# Many diseases and pests are restricted to particular hosts.
#
# Useful identification features include:
#
# - leaf shape;
# - leaf arrangement;
# - bark;
# - buds;
# - twigs;
# - flowers;
# - fruit;
# - branching pattern;
# - overall form;
# - municipal tree tags.
#
# Species uncertainty should be recorded explicitly.
#
# Possible confidence categories include:
#
# - confirmed species;
# - probable species;
# - genus only;
# - broad group only;
# - unknown.
#
# An incorrect host identification can lead to an incorrect disease diagnosis.
# ```
#
# ```markdown
# ## 20. Individual-Tree Measurements
#
# Several measurements may be collected for each sampled tree.
#
# ### Tree Size
#
# Possible variables include:
#
# - trunk diameter;
# - estimated height;
# - crown width;
# - crown height;
# - number of major stems.
#
# ### Leaf Condition
#
# Possible variables include:
#
# - number of sampled leaves;
# - number of symptomatic leaves;
# - estimated affected leaf area;
# - number of holes;
# - number of lesions;
# - lesion size;
# - discolouration;
# - premature leaf loss.
#
# ### Crown Condition
#
# Possible variables include:
#
# - canopy density;
# - transparency;
# - crown dieback;
# - dead branches;
# - discoloured foliage;
# - asymmetrical decline.
#
# ### Trunk Condition
#
# Possible variables include:
#
# - wound height;
# - wound width;
# - wound length;
# - missing bark;
# - cracking;
# - cavities;
# - visible decay;
# - fungal structures;
# - insect holes.
#
# ### Root-Zone Condition
#
# Possible variables include:
#
# - exposed roots;
# - cut roots;
# - compacted soil;
# - restricted planting area;
# - excavation;
# - standing water;
# - mulch depth;
# - distance from road;
# - distance from construction.
# ```
#
# ```markdown
# ## 21. Measuring Disease Incidence
#
# Disease incidence describes the proportion of sampled individuals that meet a defined condition.
#
# For a sample of trees:
#
# $$
# \hat{p}
# =
# \frac{x}{n}
# $$
#
# Where:
#
# - $$x$$ = number of trees meeting the case definition;
# - $$n$$ = total number of trees examined;
# - $$\hat{p}$$ = estimated proportion affected.
#
# The percentage affected is:
#
# $$
# \text{Incidence Percentage}
# =
# \frac{x}{n}
# \times
# 100
# $$
#
# For example, if 18 of 60 sampled maple trees contain tar-spot-like symptoms:
#
# $$
# \hat{p}
# =
# \frac{18}{60}
# =
# 0.30
# $$
#
# Therefore:
#
# $$
# \text{Observed Incidence}
# =
# 30\%
# $$
#
# This does not necessarily mean that 30% of the trees are seriously ill.
#
# It means that 30% met the specific observational case definition used in the survey.
# ```
#
# ```markdown
# ## 22. Measuring Disease Severity
#
# Disease severity describes how much of an individual plant or tissue is affected.
#
# For one leaf:
#
# $$
# S_{ij}
# =
# \frac{
# A_{ij,\text{affected}}
# }{
# A_{ij,\text{total}}
# }
# $$
#
# Where:
#
# - $$S_{ij}$$ = severity for leaf $$j$$ on tree $$i$$;
# - $$A_{ij,\text{affected}}$$ = affected leaf area;
# - $$A_{ij,\text{total}}$$ = total leaf area.
#
# For a sample of leaves from one tree:
#
# $$
# S_i
# =
# \frac{1}{m_i}
# \sum_{j=1}^{m_i}
# S_{ij}
# $$
#
# Where:
#
# - $$m_i$$ = number of sampled leaves;
# - $$S_i$$ = mean estimated leaf severity for tree $$i$$.
#
# A tree may have high disease incidence among its leaves but low severity per leaf.
#
# For example:
#
# - many leaves may contain one small spot;
# - a small number of leaves may be almost completely damaged.
#
# These conditions should not be treated as equivalent.
# ```
#
# ```markdown
# ## 23. Incidence, Severity, and Whole-Tree Health
#
# Three measurements should be kept separate.
#
# ### Incidence
#
# How many plants or plant parts are affected?
#
# ### Severity
#
# How much of each plant or plant part is affected?
#
# ### Health Impact
#
# How much does the condition affect survival, growth, function, or structural stability?
#
# These relationships can be represented as:
#
# $$
# \text{Visible Incidence}
# \neq
# \text{Disease Severity}
# \neq
# \text{Whole-Plant Impact}
# $$
#
# A visually obvious foliage disease may affect many leaves but have a limited effect on the long-term survival of a mature tree.
#
# A less visible root or vascular problem may have a much greater effect.
#
# The affected tissue and biological mechanism must therefore be considered alongside numerical severity.
# ```
#
# ```markdown
# ## 24. Population Sampling
#
# Examining only damaged-looking trees would produce a biased estimate of population health.
#
# The probability that a tree is selected should not depend on whether it already appears diseased.
#
# Ideally:
#
# $$
# P(
# \text{selected}
# \mid
# \text{visibly damaged}
# )
# =
# P(
# \text{selected}
# \mid
# \text{apparently healthy}
# )
# $$
#
# Several sampling approaches are possible.
#
# ### Simple Random Sampling
#
# Trees are selected randomly from a complete inventory.
#
# This requires a reasonably complete list of trees.
#
# ### Systematic Sampling
#
# Every fixed number of trees is selected along a route.
#
# For example:
#
# - every fifth tree;
# - the nearest tree to every predetermined map point;
# - one tree every 100 metres.
#
# ### Stratified Random Sampling
#
# The tree population is divided into meaningful groups before random selection.
#
# Possible strata include:
#
# - species;
# - street;
# - park;
# - land-use type;
# - tree size;
# - planter type;
# - distance from road;
# - neighbourhood;
# - municipal management zone.
#
# ### Cluster Sampling
#
# Groups of trees or street segments are selected, and trees within those groups are examined.
#
# ### Opportunistic Observation
#
# Interesting cases are recorded whenever encountered.
#
# These records are valuable for diagnosis and discovery, but they should not be used alone to estimate population prevalence.
# ```
#
# ```markdown
# ## 25. Urban Sampling Challenges
#
# Urban tree populations are not distributed randomly.
#
# Trees may be planted:
#
# - in rows;
# - in groups of the same species;
# - during the same year;
# - in similar soil conditions;
# - under the same maintenance program;
# - along the same road;
# - near the same construction project.
#
# Nearby trees may therefore share both biological and environmental conditions.
#
# This creates spatial dependence.
#
# A cluster of disease may indicate transmission, but it may also reflect:
#
# - the same species;
# - the same planting age;
# - the same soil;
# - the same pruning history;
# - the same drought exposure;
# - the same road-salt exposure.
#
# The analysis should therefore avoid treating every tree as a completely independent observation without considering location and shared conditions.
# ```
#
# ```markdown
# ## 26. Municipal Tree Inventory Data
#
# Municipal tree inventories may provide information such as:
#
# - tree coordinates;
# - species;
# - tag number;
# - trunk diameter;
# - planting location;
# - maintenance history;
# - condition category;
# - ownership;
# - inspection date.
#
# Inventory data could be used to:
#
# - map the tree population;
# - count trees by species;
# - select random samples;
# - compare streets or parks;
# - connect field observations to known tree IDs;
# - examine spatial clusters;
# - estimate the population represented by a sample.
#
# However, inventory data may be incomplete.
#
# Possible limitations include:
#
# - missing recently planted trees;
# - removed trees remaining in the dataset;
# - incorrect coordinates;
# - outdated species identifications;
# - private trees being excluded;
# - incomplete maintenance histories;
# - inconsistent condition categories.
#
# Field verification may therefore be necessary.
# ```
#
# ```markdown
# ## 27. Working Without a Complete Inventory
#
# A study can still be conducted if no complete tree inventory is available.
#
# Possible alternatives include:
#
# - dividing streets into fixed-length segments;
# - selecting random coordinates;
# - selecting random intersections;
# - sampling every fixed number of trees;
# - creating small quadrats or plots;
# - surveying all trees within selected blocks;
# - mapping trees manually during fieldwork.
#
# The sampled area must be defined before observations are used to estimate population prevalence.
#
# For example:
#
# $$
# \text{Target Population}
# =
# \text{all public street trees within selected road segments}
# $$
#
# This is more defensible than making conclusions about all trees in the city from a small number of convenient observations.
# ```
#
# ```markdown
# ## 28. Repeated Observations Through Time
#
# A single observation may reveal the current condition but not the sequence of events.
#
# Repeated observations can show whether a symptom is:
#
# - expanding;
# - stable;
# - recovering;
# - recurring;
# - seasonal;
# - spreading to nearby trees;
# - associated with weather;
# - associated with maintenance activity.
#
# For severity measured at two times:
#
# $$
# \Delta S_i
# =
# S_i(t_2)
# -
# S_i(t_1)
# $$
#
# Where:
#
# - $$S_i(t_1)$$ = severity at the first observation;
# - $$S_i(t_2)$$ = severity at the later observation;
# - $$\Delta S_i$$ = change in severity.
#
# If:
#
# $$
# \Delta S_i > 0
# $$
#
# the measured severity increased.
#
# If:
#
# $$
# \Delta S_i < 0
# $$
#
# the measured severity decreased.
#
# Repeated measurements should ideally use:
#
# - the same tree;
# - the same tissue category;
# - the same measurement method;
# - similar photograph angles;
# - similar sampling effort.
# ```
#
# ```markdown
# ## 29. Environmental and Contextual Data
#
# Plant observations may be compared with environmental variables.
#
# Possible data include:
#
# - temperature;
# - rainfall;
# - drought indices;
# - soil moisture;
# - humidity;
# - wind;
# - storm events;
# - flooding;
# - road-salt application;
# - air pollution;
# - construction history;
# - pruning schedules;
# - irrigation;
# - soil type;
# - canopy cover;
# - impervious surface;
# - distance from roads;
# - distance from buildings.
#
# A conceptual model might be:
#
# $$
# Y_i
# =
# \beta_0
# +
# \beta_1 T_i
# +
# \beta_2 M_i
# +
# \beta_3 C_i
# +
# \beta_4 R_i
# +
# \epsilon_i
# $$
#
# Where:
#
# - $$Y_i$$ = observed disease or damage severity;
# - $$T_i$$ = temperature exposure;
# - $$M_i$$ = moisture condition;
# - $$C_i$$ = soil compaction or construction disturbance;
# - $$R_i$$ = road-related exposure;
# - $$\epsilon_i$$ = unexplained variation.
#
# This model should not be interpreted causally without an appropriate study design.
#
# It is initially a way to investigate associations.
# ```
#
# ```markdown
# ## 30. Spatial Analysis
#
# Tree observations can be represented as geographic points.
#
# Each point may contain attributes describing:
#
# - species;
# - health condition;
# - symptom type;
# - severity;
# - suspected cause;
# - observation date;
# - confidence;
# - photographs;
# - nearby environmental conditions.
#
# Spatial analysis may investigate:
#
# - clusters of symptoms;
# - patterns by species;
# - patterns along roads;
# - relationships with parks;
# - relationships with construction;
# - relationships with drainage;
# - relationships with heat exposure;
# - relationships with impervious surfaces;
# - disease spread through time.
#
# A cluster does not automatically prove biological transmission.
#
# Spatial clustering can also result from shared planting, soil, weather, age, or management conditions.
# ```
#
# ```markdown
# ## 31. Potential Data Tables
#
# Later notebooks may create several related datasets.
#
# ### Tree Inventory Table
#
# One row per known tree.
#
# ### Observation Table
#
# One row per tree visit.
#
# ### Symptom Table
#
# One row per symptom observed during a visit.
#
# ### Leaf Sample Table
#
# One row per sampled leaf.
#
# ### Photograph Table
#
# One row per photograph.
#
# ### Environmental Table
#
# One row per location and observation period.
#
# ### Treatment Table
#
# One row per management action.
#
# ### Diagnostic Evidence Table
#
# One row per proposed diagnosis and evidence item.
#
# Separating these tables may be more useful than storing every measurement in one extremely wide table.
# ```
#
# ```markdown
# ## 32. Example Relational Structure
#
# A possible relationship between tables is:
#
# $$
# \text{Tree}
# \rightarrow
# \text{Observation}
# \rightarrow
# \text{Symptom}
# \rightarrow
# \text{Evidence}
# $$
#
# A single tree may have many observations.
#
# A single observation may contain many symptoms.
#
# A single symptom may have several possible explanations and several pieces of evidence.
#
# Conceptually:
#
# | Table | Primary Identifier |
# |---|---|
# | Tree | Tree ID |
# | Observation | Observation ID |
# | Symptom | Symptom ID |
# | Photograph | Photograph ID |
# | Treatment | Treatment ID |
# | Diagnosis | Diagnosis ID |
#
# This structure would allow the same tree to be followed across multiple seasons without replacing earlier records.
# ```
#
# ```markdown
# ## 33. Possible Treatments and Management Responses
#
# Treatment should follow diagnosis whenever possible.
#
# The wrong treatment may:
#
# - fail to solve the problem;
# - waste resources;
# - damage beneficial organisms;
# - create environmental contamination;
# - conceal symptoms;
# - delay an appropriate response;
# - increase pathogen spread.
#
# Possible management categories include:
#
# ### Monitoring
#
# Used when the issue is uncertain, minor, stable, or likely to recover.
#
# ### Environmental Improvement
#
# Examples include:
#
# - appropriate watering;
# - improving drainage;
# - reducing compaction;
# - protecting roots;
# - correcting mulch depth;
# - reducing repeated physical disturbance.
#
# ### Sanitation
#
# Examples may include:
#
# - removal of infected debris;
# - cleaning tools;
# - proper disposal of infected material;
# - preventing movement of contaminated soil or wood.
#
# ### Pruning
#
# Pruning may remove:
#
# - dead branches;
# - structurally unsafe branches;
# - heavily infected tissue;
# - branches that interfere with recovery.
#
# Pruning should be performed using appropriate methods and timing.
#
# ### Biological Management
#
# Possible approaches may involve:
#
# - natural predators;
# - microbial competition;
# - resistant plant varieties;
# - ecological management.
#
# ### Chemical Treatment
#
# Possible treatments may include fungicides, bactericides, insecticides, or other regulated products.
#
# Chemical recommendations should not be made from uncertain visual identification alone.
#
# ### Removal
#
# Removal may be considered when:
#
# - structural risk is unacceptable;
# - decline is irreversible;
# - the plant presents a major transmission risk;
# - treatment is impractical;
# - required by professional or regulatory guidance.
#
# Treatment decisions should be connected to the seriousness of the condition, confidence of diagnosis, cost, ecological consequences, and probability of recovery.
# ```
#
# ```markdown
# ## 34. Evaluating Treatment Effectiveness
#
# A treatment should be treated as an intervention that can be evaluated.
#
# For a treated group and comparison group:
#
# $$
# \text{Treatment Effect}
# =
# \Delta S_{\text{treated}}
# -
# \Delta S_{\text{comparison}}
# $$
#
# Where:
#
# - $$\Delta S_{\text{treated}}$$ = change in severity among treated plants;
# - $$\Delta S_{\text{comparison}}$$ = change in severity among untreated or differently managed plants.
#
# Useful outcomes may include:
#
# - reduced symptom expansion;
# - reduced new infections;
# - improved canopy growth;
# - reduced mortality;
# - improved structural stability;
# - reduced pest abundance;
# - improved soil or moisture conditions.
#
# Without comparison data, improvement after treatment does not necessarily prove that the treatment caused the improvement.
#
# The plant may have recovered naturally or environmental conditions may have changed.
# ```
#
# ```markdown
# ## 35. Ethical and Safety Limits
#
# The investigation should avoid causing additional injury or spreading possible pathogens.
#
# Fieldwork should not involve:
#
# - cutting living tissue without permission;
# - drilling into trees;
# - removing bark;
# - digging around roots;
# - breaking branches;
# - transferring material between plants;
# - entering restricted property;
# - applying treatments without authorization;
# - collecting protected organisms;
# - disturbing active wildlife habitat.
#
# Basic precautions may include:
#
# - photographing before touching;
# - using clean equipment;
# - avoiding contact between trees;
# - cleaning reusable tools;
# - recording observations non-destructively;
# - reporting dangerous branches rather than approaching them.
#
# Public trees should not be experimentally treated, pruned, sampled destructively, or altered without municipal permission.
# ```
#
# ```markdown
# ## 36. Limits of a Low-Budget Field Study
#
# Some variables cannot be measured directly with limited resources.
#
# Potential limitations include:
#
# - hidden root decay;
# - internal trunk decay;
# - vascular obstruction;
# - microscopic organisms;
# - exact fungal species;
# - bacterial species;
# - viral infection;
# - soil pathogens;
# - chemical contamination;
# - historical injury;
# - private maintenance records;
# - complete root loss;
# - tree genetics;
# - underground root connections.
#
# For example, directly measuring the percentage of infected root tissue might require excavation or destructive sampling.
#
# That could seriously damage or kill the tree.
#
# Instead, the study may rely on indirect indicators such as:
#
# - crown decline;
# - fungal structures near the base;
# - root-collar abnormalities;
# - soil conditions;
# - leaning;
# - reduced growth;
# - professional inspection.
#
# The notebook should distinguish between:
#
# - directly observed variables;
# - estimated variables;
# - inferred variables;
# - inaccessible variables.
# ```
#
# ```markdown
# ## 37. False Positives and False Negatives
#
# Field diagnosis can produce two major forms of error.
#
# ### False Positive
#
# A healthy or low-concern condition is incorrectly classified as serious disease.
#
# Examples might include:
#
# - harmless lichen identified as a pathogen;
# - normal bark shedding identified as tissue destruction;
# - cosmetic leaf spots identified as whole-tree decline.
#
# ### False Negative
#
# A serious condition is incorrectly classified as harmless.
#
# Examples might include:
#
# - internal decay overlooked because the crown remains green;
# - root damage missed because roots are underground;
# - early vascular disease missed before severe symptoms appear.
#
# These errors can be represented as:
#
# | Actual Condition | Classified Healthy | Classified Unhealthy |
# |---|---|---|
# | Healthy or Low Concern | Correct Negative | False Positive |
# | Unhealthy or Serious | False Negative | Correct Positive |
#
# The consequences of each error may differ.
#
# A false positive may create unnecessary concern or treatment.
#
# A false negative may allow a dangerous or spreading condition to remain undetected.
# ```
#
# ```markdown
# ## 38. Bias in Observation
#
# Several forms of bias may influence the study.
#
# ### Selection Bias
#
# Damaged trees are more likely to be noticed and recorded.
#
# ### Confirmation Bias
#
# Evidence supporting an expected explanation receives more attention than contradictory evidence.
#
# ### Availability Bias
#
# A recently learned disease may be assigned too frequently because it is easy to remember.
#
# ### Observer Bias
#
# Different observers may score the same tree differently.
#
# ### Detection Bias
#
# Large, colourful, or dramatic symptoms are easier to detect than hidden or subtle conditions.
#
# ### Spatial Bias
#
# Convenient streets and parks may be sampled more often than other locations.
#
# ### Seasonal Bias
#
# Some diseases are visible only during particular times of year.
#
# Bias should be reduced through:
#
# - predefined sampling;
# - standardized field cards;
# - repeated observations;
# - photographs;
# - multiple observers;
# - written case definitions;
# - blind scoring where possible;
# - preservation of uncertain classifications.
# ```
#
# ```markdown
# ## 39. Distinguishing Correlation from Cause
#
# Trees near a road may show greater damage than trees in a park.
#
# This pattern could be associated with:
#
# - road salt;
# - soil compaction;
# - heat;
# - air pollution;
# - restricted roots;
# - pruning;
# - vehicle damage;
# - species selection;
# - tree age;
# - irrigation differences.
#
# A statistical association does not by itself identify which factor caused the condition.
#
# In general:
#
# $$
# P(Y \mid X)
# \neq
# P(Y \mid \text{intervention on } X)
# $$
#
# Observing that disease is common where a factor occurs is not the same as proving that changing the factor would change disease.
#
# Causal claims require stronger evidence, such as:
#
# - temporal order;
# - biological mechanism;
# - comparison groups;
# - controlled intervention;
# - repeated patterns;
# - exclusion of major alternative explanations.
# ```
#
# ```markdown
# ## 40. Climate Change and Emerging Conditions
#
# Changing climate conditions may influence urban plant health through:
#
# - warmer average temperatures;
# - extreme heat;
# - drought;
# - intense rainfall;
# - flooding;
# - milder winters;
# - altered insect survival;
# - altered fungal development;
# - longer growing seasons;
# - changing host ranges;
# - changing vector ranges;
# - new interactions between organisms.
#
# Climate change may increase the probability of some diseases or pests occurring in new locations.
#
# However, an unusual local observation should not automatically be attributed to climate change.
#
# The study should ask:
#
# - Is the organism confirmed?
# - Was it previously absent from the region?
# - Is its range changing?
# - Are similar changes reported elsewhere?
# - Are long-term records available?
# - Could ordinary local conditions explain the observation?
#
# Climate change should be treated as a possible background driver that alters probabilities, not as an automatic diagnosis for every new symptom.
# ```
#
# ```markdown
# ## 41. From Suspicion to Defensible Conclusion
#
# A defensible conclusion should summarize:
#
# 1. what was observed;
# 2. how it was measured;
# 3. which explanations were considered;
# 4. which evidence supported each explanation;
# 5. which evidence contradicted each explanation;
# 6. what information remains unavailable;
# 7. the confidence level;
# 8. the seriousness of the condition;
# 9. whether further investigation is needed;
# 10. whether treatment or reporting is appropriate.
#
# A conclusion might take the form:
#
# **Observation:**
# Several maple leaves contained raised black lesions.
#
# **Provisional interpretation:**
# The lesions are consistent with a common foliar fungal condition.
#
# **Alternative explanations:**
# Other leaf-spot conditions remain possible.
#
# **Current seriousness:**
# Leaf symptoms are visually widespread, but whole-tree decline has not been established.
#
# **Evidence required:**
# Host confirmation, closer examination of lesion structure, seasonal monitoring, and comparison with unaffected trees.
#
# **Confidence:**
# Moderate for the symptom category, low for the exact species identification.
#
# This format prevents the notebook from claiming more than the evidence demonstrates.
# ```
#
# ```markdown
# ## 42. Proposed Notebook Series
#
# This introductory notebook can be followed by a series of more focused investigations.
#
# ### 02. Causes of Plant Illness
#
# A detailed study of pathogens, insects, environmental stress, physical injury, and interacting causes.
#
# ### 03. Plant Defence and Recovery
#
# Physical barriers, chemical defences, compartmentalization, tissue shedding, microbial interactions, and regrowth.
#
# ### 04. Tree and Disease Identification
#
# Methods for identifying host species, symptoms, signs, pests, fungi, and disease categories.
#
# ### 05. Urban Tree Inventory
#
# Collection and analysis of municipal tree data, species distributions, tree density, and sampling frames.
#
# ### 06. Field Sampling Design
#
# Random sampling, stratified sampling, systematic routes, field forms, observer consistency, and bias.
#
# ### 07. Measuring Plant Condition
#
# Leaf area loss, disease incidence, severity, crown dieback, bark damage, branch damage, and root-zone stress.
#
# ### 08. Spatial Analysis of Plant Illness
#
# Mapping symptoms, clustering, environmental exposure, species patterns, and possible spread.
#
# ### 09. Temporal Monitoring
#
# Repeated observations, seasonal patterns, weather relationships, progression, and recovery.
#
# ### 10. Diagnostic Decision System
#
# Development of a question tree or computational decision-support system for narrowing possible causes.
#
# ### 11. Treatment and Management
#
# Monitoring, sanitation, pruning, environmental improvement, biological control, chemical treatment, and removal.
#
# ### 12. Waterloo Urban Plant Health Study
#
# Application of the complete methodology to selected streets, parks, and tree populations.
# ```
#
# ```markdown
# ## 43. Planned Computational Work
#
# Later notebooks may use Python packages including:
#
# - `pandas` for tables;
# - `numpy` for numerical analysis;
# - `matplotlib` for static plots;
# - `plotly` for interactive plots;
# - `geopandas` for spatial data;
# - `shapely` for geometry;
# - `scipy` for statistical methods;
# - `statsmodels` for statistical models;
# - `scikit-learn` for exploratory classification;
# - `Pillow` or `opencv` for image measurements;
# - `rasterio` for environmental raster data.
#
# Possible outputs include:
#
# - species-count bar charts;
# - disease-incidence charts;
# - severity distributions;
# - maps of observations;
# - timelines;
# - comparisons among streets;
# - comparisons among species;
# - leaf-area measurements;
# - environmental correlation plots;
# - interactive diagnostic tools.
#
# The first computational goal should not be automated diagnosis.
#
# The first goal should be clean, consistent, interpretable data.
# ```
#
# ```markdown
# ## 44. Placeholder for Future Data Loading
#
# A later notebook may begin with a structure similar to the following:
#
# - load the municipal tree inventory;
# - load field observations;
# - validate coordinates;
# - standardize species names;
# - standardize symptom categories;
# - connect observations to tree IDs;
# - separate confirmed and uncertain diagnoses;
# - calculate incidence and severity;
# - map the results;
# - compare groups;
# - evaluate uncertainty.
#
# No analysis should begin until the case definitions and sampling design are documented.
# ```
#
# ```markdown
# ## 45. Core Methodological Principles
#
# The complete study will follow several core principles.
#
# 1. A symptom is not automatically a diagnosis.
#
# 2. Visible damage does not always indicate serious whole-plant decline.
#
# 3. Serious conditions are not always visually dramatic.
#
# 4. Several causes may act in sequence or simultaneously.
#
# 5. The visible organism may be a primary pathogen, secondary pathogen, opportunist, or decomposer.
#
# 6. Host species must be considered before assigning a disease.
#
# 7. Healthy-looking trees must be sampled alongside damaged trees.
#
# 8. Opportunistic observations should be separated from statistical samples.
#
# 9. Incidence, severity, and biological impact are different measurements.
#
# 10. Leaves, branches, trunks, crowns, and roots should be evaluated separately.
#
# 11. Repeated observations are needed to measure progression.
#
# 12. Spatial clusters do not automatically prove transmission.
#
# 13. Correlation does not automatically establish cause.
#
# 14. Treatments should follow evidence-based diagnosis.
#
# 15. Uncertainty must be recorded rather than hidden.
#
# 16. Destructive investigation should not be performed without permission and appropriate expertise.
#
# 17. Strong conclusions require evidence capable of excluding plausible alternatives.
# ```
#
# ```markdown
# ## 46. Conclusion
#
# The analysis of plant illness begins with careful observation, but it cannot end there.
#
# A complete methodology must connect field observations to host identification, symptom description, environmental context, biological mechanisms, competing hypotheses, population sampling, severity measurements, spatial patterns, temporal change, and treatment evaluation.
#
# The central process developed in this notebook is:
#
# $$
# \boxed{
# \text{Observe}
# \rightarrow
# \text{Describe}
# \rightarrow
# \text{Classify}
# \rightarrow
# \text{Measure}
# \rightarrow
# \text{Compare Hypotheses}
# \rightarrow
# \text{Collect Additional Evidence}
# \rightarrow
# \text{Evaluate Seriousness}
# \rightarrow
# \text{Conclude}
# \rightarrow
# \text{Monitor or Treat}
# }
# $$
#
# This approach allows unusual or concerning possibilities to be investigated without accepting them prematurely.
#
# It also prevents common or harmless processes from being dismissed without examination.
#
# The purpose of the project is therefore not merely to create a list of plant diseases.
#
# Its purpose is to create a systematic framework for deciding:
#
# - what happened;
# - what may have caused it;
# - how confidently it can be identified;
# - how serious it is;
# - how common it is in the population;
# - whether it is changing;
# - and what response, if any, is justified.
# ```
